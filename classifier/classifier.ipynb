# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
import joblib
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
sample_file_path="./samples.csv"
df_site=pd.read_csv(sample_file_path)

# %%
df_site
# Out:
#        id                          url  \
# 0     720           http://codgen.uno/
# 1     721              http://esto.es/
# 2     722  http://gg.gg/child_cartoons
# 3     723            http://gmail.com/
# 4     724              http://hair.so/
# ..    ...                          ...
# 426  1146            http://4.FO/JiMaT
# 427  1147           http://cliick.fun/
# 428  1148          http://hotwife.uno/
# 429  1149         http://porngirl.uno/
# 430  1150           http://amoera.cam/
#
#                                           landing_page  a_count  img_count  \
# 0               https://freegameresource.com/22500rbx/        0         13
# 1                           http://esto.es/defaultsite        0          0
# 2                                        http://gg.gg/       13          6
# 3    https://accounts.google.com/v3/signin/identifi...        6          1
# 4                                     https://hair.so/      180         47
# ..                                                 ...      ...        ...
# 426                https://dhaaeh.datinglocator24.com/        0          0
# 427  https://odzrea.speciaidates.com/c/1e3a4e532f1c...        5         35
# 428  https://dirtyflirt6.com/?a=1192171&cr=48591&li...       10          0
# 429  https://moartraffic.engine.adglare.net/?290938...        0          0
# 430  https://racywomenm0.com/?a=1829848&cr=48591&li...       10          0
#
#      iframe_count  button_count  div_count  class_count  words_count  ...  \
# 0               1             2         23           24          102  ...
# 1               0             0          1            0            0  ...
# 2               2             0         16            4          289  ...
# 3               1             1         26           40          753  ...
# 4               1            32        333           88         5177  ...
# ..            ...           ...        ...          ...          ...  ...
# 426             0             0          0            0            7  ...
# 427             0            13        149          124          935  ...
# 428             0             0         50           33          356  ...
# 429             0             0          0            0            1  ...
# 430             0             0         40           28          356  ...
#
#      link_count    a_http   a_https  link_http  link_https    a_diff  \
# 0             6  0.000000  0.000000        0.0    0.333333  0.000000
# 1             0  0.000000  0.000000        0.0    0.000000  0.000000
# 2             5  0.692308  0.000000        1.0    0.000000  0.153846
# 3             1  0.000000  1.000000        0.0    1.000000  0.333333
# 4             3  0.000000  0.772222        0.0    1.000000  0.027778
# ..          ...       ...       ...        ...         ...       ...
# 426           0  0.000000  0.000000        0.0    0.000000  0.000000
# 427           5  0.000000  0.200000        0.0    1.000000  0.000000
# 428           0  0.000000  0.300000        0.0    0.000000  0.000000
# 429           0  0.000000  0.000000        0.0    0.000000  0.000000
# 430           1  0.000000  0.300000        0.0    1.000000  0.000000
#
#      link_diff  a_hashtag  link_hashtag  tag
# 0     0.333333   0.000000           0.0    1
# 1     0.000000   0.000000           0.0    1
# 2     0.000000   0.307692           0.0    1
# 3     0.000000   0.000000           0.0    1
# 4     0.333333   0.000000           0.0    1
# ..         ...        ...           ...  ...
# 426   0.000000   0.000000           0.0    0
# 427   0.000000   0.800000           0.0    0
# 428   0.000000   0.700000           0.0    0
# 429   0.000000   0.000000           0.0    0
# 430   1.000000   0.700000           0.0    0
#
# [431 rows x 21 columns]

# %%
X, y = df_site.iloc[:, 3:-2].values, df_site.iloc[:,-1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)

# %%
mms=MinMaxScaler()

# %%
X_train_norm=mms.fit_transform(X_train) # 最大-最小特征缩放

# %%
X_test_norm=mms.fit_transform(X_test)

# %%
stdsc=StandardScaler()
X_train_std=stdsc.fit_transform(X_train)
X_test_std=stdsc.fit_transform(X_test)

# %%
lr=LogisticRegression(C=1.0,random_state=1,solver='lbfgs',multi_class='multinomial')
lr.fit(X_train_std, y_train)
y_pred=lr.predict(X_test_std)
print('accuracy_score: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# accuracy_score: 0.977

# %%
svm = SVC(kernel='rbf', random_state=1, gamma='scale', C=1.0)
svm.fit(X_train_std, y_train)
y_pred = svm.predict(X_test_std)
print('accuracy_score: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# accuracy_score: 0.969

# %%
tree_model=DecisionTreeClassifier(criterion='gini',max_depth=5,random_state=30)
tree_model.fit(X_train_std,y_train)
y_pred = tree_model.predict(X_test_std)
print('accuracy_score: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# accuracy_score: 0.900

# %%
joblib.dump(lr,'lr.pkl',compress=3)
# Out:
# ['lr.pkl']

# %%
lr_model = joblib.load('lr.pkl')
